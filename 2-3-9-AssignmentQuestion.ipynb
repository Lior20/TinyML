# %% [markdown]
# # Create a CNN to classify Cifar-10
#
# Learn about Cifar-10 here: https://www.cs.toronto.edu/~kriz/cifar.html
#
# In class you saw how to build a Convolutional Neural Network that classified Fashion MNIST. Take what you learned to build a CNN that recognizes the 10 classes of CIFAR. It will be a similar network, but there are some key differences you'll need to take into account.
#
# First, while MNIST were 28x28 monochome images (1 color channel), CIFAR are 32x32 color images (3 color channels).
#
# Second, MNIST images are simple, containing just the object, centered in the image, with no background. CIFAR ones can have the object with a background -- for example airplanes might have a cloudy sky behind them! As such you should expect your accuracy to be a bit lower.
#
# We start by setting up the problem for you.

# %%
import tensorflow as tf

from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

# Normalize pixel values to be between 0 and 1
train_images = train_images / 255.0
test_images = test_images / 255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 12s 0us/step

# %% [markdown]
# We then definte some of the model for you but leave most of it for you to fill in!
#
# *A hint: your model may want to learn some high level features and then classify them.*

# %%
FIRST_LAYER = tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(32, 32, 3))
HIDDEN_LAYER_TYPE_1 = tf.keras.layers.MaxPooling2D(2,2)
HIDDEN_LAYER_TYPE_2 = tf.keras.layers.Conv2D(64, (3,3), activation='relu')
HIDDEN_LAYER_TYPE_3 = tf.keras.layers.MaxPooling2D(2,2)
HIDDEN_LAYER_TYPE_4 = tf.keras.layers.Conv2D(64, (3,3), activation='relu')
HIDDEN_LAYER_TYPE_5 = tf.keras.layers.Dense(20, activation=tf.nn.relu)
LAST_LAYER = tf.keras.layers.Dense(10, activation=tf.nn.softmax)

model = models.Sequential([
       FIRST_LAYER,
       HIDDEN_LAYER_TYPE_1,
       HIDDEN_LAYER_TYPE_2,
       HIDDEN_LAYER_TYPE_3,
       HIDDEN_LAYER_TYPE_4,
       layers.Flatten(),
       HIDDEN_LAYER_TYPE_5,
       LAST_LAYER,
])

# %% [markdown]
# You then need to define loss function. And you can then train your model. Once training is done you'll see a plot of training and validation accuracy. You'll know you have a reasonable model with a reasonable loss funciton if your final training accuracy ends up in the 70s (or possibly higher).
#
# *A hint: your model may want to learn different categories.*

# %%
LOSS = 'sparse_categorical_crossentropy'
NUM_EPOCHS = 20 #You can change this value if you like to experiment with it to get better accuracy

# Compile the model
model.compile(optimizer='sgd',
              loss=LOSS,
              metrics=['accuracy'])

# Fit the model
history = model.fit(train_images, train_labels, epochs=NUM_EPOCHS,
                    validation_data=(test_images, test_labels))

# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.xlim([0,NUM_EPOCHS])
plt.ylim([0.4,1.0])
plt.show()
# Out:
# Epoch 1/20
# 1563/1563 [==============================] - 19s 6ms/step - loss: 2.2008 - accuracy: 0.1761 - val_loss: 2.0224 - val_accuracy: 0.2702
# Epoch 2/20
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.8185 - accuracy: 0.3433 - val_loss: 1.6351 - val_accuracy: 0.4048
# Epoch 3/20
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.5760 - accuracy: 0.4280 - val_loss: 1.5723 - val_accuracy: 0.4428
# Epoch 4/20
# 1563/1563 [==============================] - 9s 5ms/step - loss: 1.4369 - accuracy: 0.4799 - val_loss: 1.3462 - val_accuracy: 0.5174
# Epoch 5/20
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.3380 - accuracy: 0.5191 - val_loss: 1.3053 - val_accuracy: 0.5321
# Epoch 6/20
# 1563/1563 [==============================] - 9s 5ms/step - loss: 1.2598 - accuracy: 0.5506 - val_loss: 1.2876 - val_accuracy: 0.5464
# Epoch 7/20
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.1894 - accuracy: 0.5810 - val_loss: 1.1814 - val_accuracy: 0.5683
# Epoch 8/20
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.1283 - accuracy: 0.6031 - val_loss: 1.1232 - val_accuracy: 0.5974
# Epoch 9/20
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.0718 - accuracy: 0.6241 - val_loss: 1.0852 - val_accuracy: 0.6157
# Epoch 10/20
# 1563/1563 [==============================] - 9s 5ms/step - loss: 1.0288 - accuracy: 0.6403 - val_loss: 1.0524 - val_accuracy: 0.6286
# Epoch 11/20
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.9866 - accuracy: 0.6551 - val_loss: 1.1261 - val_accuracy: 0.6051
# Epoch 12/20
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.9515 - accuracy: 0.6687 - val_loss: 1.0269 - val_accuracy: 0.6393
# Epoch 13/20
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.9158 - accuracy: 0.6806 - val_loss: 1.0561 - val_accuracy: 0.6294
# Epoch 14/20
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.8860 - accuracy: 0.6922 - val_loss: 0.9598 - val_accuracy: 0.6636
# Epoch 15/20
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.8549 - accuracy: 0.7019 - val_loss: 0.9288 - val_accuracy: 0.6760
# Epoch 16/20
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.8253 - accuracy: 0.7124 - val_loss: 0.9718 - val_accuracy: 0.6596
# Epoch 17/20
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.7998 - accuracy: 0.7203 - val_loss: 0.9205 - val_accuracy: 0.6777
# Epoch 18/20
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.7766 - accuracy: 0.7298 - val_loss: 0.9826 - val_accuracy: 0.6685
# Epoch 19/20
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.7527 - accuracy: 0.7393 - val_loss: 0.9866 - val_accuracy: 0.6639
# Epoch 20/20
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.7324 - accuracy: 0.7446 - val_loss: 0.8950 - val_accuracy: 0.6964

# %% [markdown]
# Finally, pick a better optimizer. And re-train your model. You'll know you have a reasonable model with a reasonable loss funciton and optimizer if your final training accuracy ends up in the 80s (or possibly higher).
#
# *A hint: your model may want to learn adaptively.*

# %%
OPTIMIZER = 'Adagrad'

# Compile the model
model.compile(optimizer=OPTIMIZER,
              loss=LOSS,
              metrics=['accuracy'])

# Fit the model
history = model.fit(train_images, train_labels, epochs=NUM_EPOCHS,
                    validation_data=(test_images, test_labels))

# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.xlim([0,NUM_EPOCHS])
plt.ylim([0.4,1.0])
plt.show()
# Out:
# Epoch 1/20
# 1563/1563 [==============================] - 11s 6ms/step - loss: 0.0989 - accuracy: 0.9677 - val_loss: 1.4575 - val_accuracy: 0.7217
# Epoch 2/20
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.0758 - accuracy: 0.9779 - val_loss: 1.4809 - val_accuracy: 0.7199
# Epoch 3/20
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.0675 - accuracy: 0.9816 - val_loss: 1.4935 - val_accuracy: 0.7208
# Epoch 4/20
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.0622 - accuracy: 0.9838 - val_loss: 1.5087 - val_accuracy: 0.7211
# Epoch 5/20
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.0584 - accuracy: 0.9852 - val_loss: 1.5172 - val_accuracy: 0.7209
# Epoch 6/20
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.0555 - accuracy: 0.9867 - val_loss: 1.5265 - val_accuracy: 0.7219
# Epoch 7/20
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.0531 - accuracy: 0.9876 - val_loss: 1.5351 - val_accuracy: 0.7212
# Epoch 8/20
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.0511 - accuracy: 0.9885 - val_loss: 1.5428 - val_accuracy: 0.7219
# Epoch 9/20
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.0494 - accuracy: 0.9893 - val_loss: 1.5515 - val_accuracy: 0.7230
# Epoch 10/20
# 1563/1563 [==============================] - 9s 5ms/step - loss: 0.0479 - accuracy: 0.9899 - val_loss: 1.5592 - val_accuracy: 0.7218
# Epoch 11/20
# 1563/1563 [==============================] - 9s 5ms/step - loss: 0.0465 - accuracy: 0.9904 - val_loss: 1.5663 - val_accuracy: 0.7227
# Epoch 12/20
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.0453 - accuracy: 0.9908 - val_loss: 1.5722 - val_accuracy: 0.7220
# Epoch 13/20
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.0442 - accuracy: 0.9914 - val_loss: 1.5776 - val_accuracy: 0.7219
# Epoch 14/20
# 1563/1563 [==============================] - 9s 5ms/step - loss: 0.0432 - accuracy: 0.9918 - val_loss: 1.5838 - val_accuracy: 0.7219
# Epoch 15/20
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.0423 - accuracy: 0.9920 - val_loss: 1.5889 - val_accuracy: 0.7221
# Epoch 16/20
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.0414 - accuracy: 0.9923 - val_loss: 1.5937 - val_accuracy: 0.7217
# Epoch 17/20
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.0407 - accuracy: 0.9924 - val_loss: 1.5991 - val_accuracy: 0.7223
# Epoch 18/20
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.0399 - accuracy: 0.9928 - val_loss: 1.6047 - val_accuracy: 0.7226
# Epoch 19/20
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.0392 - accuracy: 0.9930 - val_loss: 1.6091 - val_accuracy: 0.7222
# Epoch 20/20
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.0386 - accuracy: 0.9931 - val_loss: 1.6138 - val_accuracy: 0.7227
